# %%
# !gdown "1B9A9UCJYMwTL4oBEo4RZfbMZMaZhKJaz&confirm=t"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1B9A9UCJYMwTL4oBEo4RZfbMZMaZhKJaz&confirm=t
# To: D:\DeepLabV3+\instance-level-human-parsing.zip
#
#   0%|          | 0.00/2.91G [00:00<?, ?B/s]
#   0%|          | 524k/2.91G [00:02<4:26:49, 182kB/s]
#   0%|          | 1.05M/2.91G [00:03<2:27:02, 330kB/s]
#   0%|          | 1.57M/2.91G [00:06<3:15:22, 248kB/s]
#   0%|          | 2.10M/2.91G [00:07<2:32:44, 318kB/s]
#   0%|          | 3.67M/2.91G [00:08<1:19:29, 610kB/s]
#   0%|          | 5.24M/2.91G [00:08<49:03, 988kB/s]
#   0%|          | 5.77M/2.91G [00:09<44:01, 1.10MB/s]
#   0%|          | 6.29M/2.91G [00:09<39:42, 1.22MB/s]
#   0%|          | 6.82M/2.91G [00:09<36:21, 1.33MB/s]
#   0%|          | 7.34M/2.91G [00:10<56:29, 857kB/s]
#   0%|          | 7.86M/2.91G [00:11<49:36, 976kB/s]
#   0%|          | 8.39M/2.91G [00:14<1:48:38, 445kB/s]
#   0%|          | 10.5M/2.91G [00:14<46:33, 1.04MB/s]
#   0%|          | 11.0M/2.91G [00:15<52:13, 926kB/s]
# ...

# %%
# !pip install unzip
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for unzip: filename=unzip-1.0.0-py3-none-any.whl size=1279 sha256=a60d96956f415dbe1ff4241fcdc71060041c43e2c493411c6955b075be33008c
#   Stored in directory: c:\users\tasmim\appdata\local\pip\cache\wheels\88\2c\2b\d12ab5bb9f34eba42f98231b969311f33d7dc1a2f484b902d1
# Successfully built unzip
# ...

# %%
# !unzip -q instance-level-human-parsing.zip
# Out:
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.
